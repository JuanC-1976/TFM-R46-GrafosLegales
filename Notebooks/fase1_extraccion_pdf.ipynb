# %% [markdown]
# # Fase 1 - Extracción de Artículos desde PDFs Jurídicos
# Esta Fase se lee documentos PDF legales desde la carpeta `data/`, los limpia, extrae los artículos y normaliza su contenido.

# %%
# !pip install PyMupdf -q
# !pip install pandas -q

# %%
import os
import requests
import fitz  # PyMuPDF
import re
import unicodedata
import json
from pathlib import Path
from collections import Counter
import pandas as pd

# %%
# Lista de URLs crudas (RAW) de GitHub
archivos_pdf = [
    {
        "nombre": "LOPDGDD_2018",
        "url": "https://raw.githubusercontent.com/JuanC-1976/TFM-R46-GrafosLegales/main/BOE-A-2018-16673.pdf",
        "tipo_documento": "Ley Orgánica",
        "fecha_publicacion": "2018-12-06",
        "entidad_normativa": "BOE",
        "es_oficial": True
    },
    {
        "nombre": "RGPD",
        "url": "https://raw.githubusercontent.com/JuanC-1976/TFM-R46-GrafosLegales/main/CELEX_32016R0679_ES_TXT.pdf",
        "tipo_documento": "Reglamento Europeo",
        "fecha_publicacion": "2016-04-27",
        "entidad_normativa": "Parlamento Europeo",
        "es_oficial": True
    },
    {
        "nombre": "GUIA_AEPD",
        "url": "https://raw.githubusercontent.com/JuanC-1976/TFM-R46-GrafosLegales/main/memoria-aepd-2024.pdf",
        "tipo_documento": "Guía Técnica",
        "fecha_publicacion": "2022-01-15",
        "entidad_normativa": "AEPD",
        "es_oficial": False
    },
    {   
        "nombre": "Ley_Organica_15_1999",
        "url": "https://raw.githubusercontent.com/JuanC-1976/TFM-R46-GrafosLegales/main/BOE-A-1999-23750-consolidado.pdf",
        "tipo_documento": "Ley Orgánica (derogada)",
        "fecha_publicacion": "1999-12-14",
        "entidad_normativa": "BOE",
        "es_oficial": True
    },
    {   
        "nombre":"Ley_13500_Andalucia",
        "url": "https://raw.githubusercontent.com/JuanC-1976/TFM-R46-GrafosLegales/main/13500.pdf",
        "tipo_documento": "Ley Autonómica",
        "fecha_publicacion": "2022-03-10",
        "entidad_normativa": "Junta de Andalucía",
        "es_oficial": True
    }
]

# %%
# Descargar PDF si no existe
def descargar_pdf_si_no_existe(doc):
    ruta_pdf = Path(f"temp_pdfs/{doc['nombre']}.pdf")
    if ruta_pdf.exists():
        print(f"[✔] Ya existe: {ruta_pdf.name}")
        return ruta_pdf

    print(f"[↓] Descargando: {doc['nombre']}")
    r = requests.get(doc["url"])
    if "application/pdf" not in r.headers.get("Content-Type", ""):
        print(f"[ERROR] No es un PDF válido: {doc['url']}")
        return None

    ruta_pdf.parent.mkdir(exist_ok=True)
    with open(ruta_pdf, "wb") as f:
        f.write(r.content)
        
        # Verificar que el PDF descargado se pueda abrir
    try:
        with fitz.open(ruta_pdf) as test_pdf:
            _ = test_pdf[0]  # fuerza lectura de primera página
    except Exception as e:
        print(f"[AVISO] PDF corrupto tras descarga: {e}")
        ruta_pdf.unlink()  # eliminar archivo dañado
        print(f"[] Reintentando descarga limpia...")
        return descargar_pdf_si_no_existe(doc)  # intento recursivo limpio
        
    return ruta_pdf

# %%
# Extraer texto desde PDF
def extraer_texto_pdf(doc):
    ruta_pdf = descargar_pdf_si_no_existe(doc)
    if not ruta_pdf:
        return None

    try:
        with fitz.open(ruta_pdf) as pdf:
            texto = "\n".join([pagina.get_text() for pagina in pdf])
            return normalizar(texto)
    except Exception as e:
        print(f"[ERROR] Fallo al leer {doc['nombre']}: {e}")
        return None

# %%
# Normaliza el texto sin perder símbolos jurídicos ni estructura básica
def normalizar(texto):
    texto = unicodedata.normalize('NFC', texto)
    texto = re.sub(r'Página\s+\d+', '', texto, flags=re.IGNORECASE)
    texto = re.sub(r'[ \t]+', ' ', texto)
    texto = re.sub(r'[^\w\s.,;:()¿?!¡ºª§«»"\'\-–\n]', '', texto)
    return texto.strip()

# %%
# Intentar extraer por artículos

articulos_totales = []
conteo_por_documento = {}    
for doc in archivos_pdf:
    nombre = doc["nombre"]
    texto = extraer_texto_pdf(doc)  
    if not texto:
        continue

    texto_limpio = texto  
    articulos = []
    
    # Patrón amplio para artículos, disposiciones, títulos, capítulos
    patron = r"(Artículo\s+\d+[ººª]?[\.:\-]?\s.*?|Artículo\s+único.*?|Disposición\s+(?:adicional|final|transitoria)\s+\w+.*?|Cap[ií]tulo\s+\w+.*?|Título\s+\w+.*?|Secci[oó]n\s+\w+.*?)(?=\s{2,}|\n|Artículo\s+|Disposición\s+|Cap[ií]tulo\s+|Título\s+|Secci[oó]n\s+|$)"
    partes = re.split(patron, texto_limpio)
    
    
    if len(partes) > 2: # División por encabezados bien formateados
        for encabezado, contenido in zip(partes[1::2], partes[2::2]):
            if len(contenido.strip()) > 50 and not contenido.lower().startswith("cve:"):
               tipo = (
                    "Artículo" if "artículo" in encabezado.lower()
                    else "Disposición" if "disposición" in encabezado.lower()
                    else "Capítulo" if "capítulo" in encabezado.lower()
                    else "Sección" if "sección" in encabezado.lower()
                    else "Otro"
               )
                
               articulos.append({
                   "Documento": nombre,
                   "Artículo N": re.search(r'\d+', encabezado).group() if re.search(r'\d+', encabezado) else encabezado.strip(),
                   "Contenido": normalizar(contenido),
                   "tipo_documento": doc.get("tipo_documento", ""),
                   "fecha_publicacion": doc.get("fecha_publicacion", ""),
                   "entidad_normativa": doc.get("entidad_normativa", ""),
                   "es_oficial": doc.get("es_oficial", False)
               })
    else:
        # Extracción por bloques alternativos
        bloques = re.findall(
            r'(Título\s+[IVXLC\d]+|Capítulo\s+[IVXLC\d]+|Sección\s+[A-Za-z]+|Disposición\s+\w+)\.?\s+(.*?)(?=Título\s+[IVXLC\d]+|Capítulo\s+[IVXLC\d]+|Sección\s+[A-Za-z]+|Disposición\s+\w+|$)',
            texto_limpio, re.DOTALL)
        for encabezado, contenido in bloques:
            if len(contenido.strip()) > 50:
                articulos.append({
                    "Documento": nombre,
                    "Artículo N": encabezado.strip(),
                    "Contenido": normalizar(contenido),
                    "tipo_documento": doc.get("tipo_documento", ""),
                    "fecha_publicacion": doc.get("fecha_publicacion", ""),
                    "entidad_normativa": doc.get("entidad_normativa", ""),
                    "es_oficial": doc.get("es_oficial", False)
                })
                
    # Vista previa en tabla
    if articulos:
        conteo_por_documento[nombre] = len(articulos)
        articulos_totales.extend(articulos)
        
        # Mostrar preview
        df_vista = pd.DataFrame(articulos)
        df_vista["Vista previa"] = df_vista["Contenido"].str.slice(0, 200) + "..."
        display(df_vista[["Documento", "Artículo N", "Vista previa"]].head(10))
        print(f" {nombre}: {len(articulos)} bloques extraídos")
      
    else:
        print(f" No se encontraron artículos o bloques válidos en {nombre}.")
        print(f"No se encontraron artículos o bloques válidos en {nombre}.")
# Out:
# [✔] Ya existe: LOPDGDD_2018.pdf
#       Documento                      Artículo N  \
# 0  LOPDGDD_2018                              20
# 1  LOPDGDD_2018                     Capítulo I.
# 2  LOPDGDD_2018                              50
# 3  LOPDGDD_2018                               2
# 4  LOPDGDD_2018                               3
# 5  LOPDGDD_2018                               2
# 6  LOPDGDD_2018                    Título VIII.
# 7  LOPDGDD_2018                              80
# 8  LOPDGDD_2018  Disposición adicional primera.
# 9  LOPDGDD_2018  Disposición adicional segunda.
#
#                                         Vista previa
# 0  cve: BOE-A-2018-16673\nVerificable en http:www...
# 1  Disposiciones generales. Medidas de responsabi...
# 2  cve: BOE-A-2018-16673\nVerificable en http:www...
# 3  Potestades de investigación y planes de audito...
# 4  Otras potestades de la Agencia Española de Pro...
# 5  Coordinación en el marco de los procedimientos...
# 6  Procedimientos en caso de posible vulneración ...
# 7  cve: BOE-A-2018-16673\nVerificable en http:www...
# 8  Medidas de seguridad en el ámbito del sector p...
# 9  Protección de datos y transparencia y acceso a...
#  LOPDGDD_2018: 231 bloques extraídos
# [✔] Ya existe: RGPD.pdf
#   Documento Artículo N                                       Vista previa
# 0      RGPD          1  Objeto \n1.\nEl presente Reglamento establece ...
# 1      RGPD          2  Ámbito de aplicación material \n1.\nEl present...
# 2      RGPD          3  Ámbito territorial \n1.\nEl presente Reglament...
# 3      RGPD          4  Definiciones \nA efectos del presente Reglamen...
# 4      RGPD          5  Principios relativos al tratamiento \n1.\nLos ...
# 5      RGPD          6  Licitud del tratamiento \n1.\nEl tratamiento s...
# 6      RGPD          7  Condiciones para el consentimiento \n1.\nCuand...
# 7      RGPD          8  Condiciones aplicables al consentimiento del n...
# 8      RGPD          9  Tratamiento de categorías especiales de datos ...
# 9      RGPD         10  Tratamiento de datos personales relativos a co...
#  RGPD: 101 bloques extraídos
# [✔] Ya existe: GUIA_AEPD.pdf
#    Documento                                    Artículo N  \
# 0  GUIA_AEPD  Sección Primera de la Sala de lo Contencioso
# 1  GUIA_AEPD     Disposición transitoria segunda LOPDPGDD,
# 2  GUIA_AEPD                                            18
# 3  GUIA_AEPD                  Capítulo V del RGPD al haber
# 4  GUIA_AEPD                                            32
# 5  GUIA_AEPD                                            25
# 6  GUIA_AEPD                                            35
# 7  GUIA_AEPD                                            32
# 8  GUIA_AEPD                                             7
# 9  GUIA_AEPD                                            37
#
#                                         Vista previa
# 0  Administrativo de la Audiencia Nacional que \n...
# 1  se continua con el proceso de adaptación de lo...
# 2  aunque haya acreditado la contestación a la \n...
# 3  declarado inválido el TJUE la anterior decisió...
# 4  falta de medidas de seguridad básicas. Multa \...
# 5  diseño desde el principio en el que los datos ...
# 6  realización de una evaluación de impacto. \nMu...
# 7  Artículo \n83.4 del RGPD, una multa de 200.000...
# 8  de inscripción no ofrecía la posibilidad de \n...
# 9  A lo largo del procedimiento se han corregido ...
#  GUIA_AEPD: 17 bloques extraídos
# [✔] Ya existe: Ley_Organica_15_1999.pdf
#               Documento                                         Artículo N  \
# 0  Ley_Organica_15_1999                                                  3
# 1  Ley_Organica_15_1999                                                 12
# 2  Ley_Organica_15_1999                                                 19
# 3  Ley_Organica_15_1999                                                 24
# 4  Ley_Organica_15_1999                                                 32
# 5  Ley_Organica_15_1999                                                 34
# 6  Ley_Organica_15_1999                                                 40
# 7  Ley_Organica_15_1999                                                 42
# 8  Ley_Organica_15_1999                                                 49
# 9  Ley_Organica_15_1999  Disposición adicional tercera. Tratamiento de ...
#
#                                         Vista previa
# 0  5\nTÍTULO II. Principios de la protección de d...
# 1  9\nTÍTULO III. Derechos de las personas . . . ...
# 2  10\nTÍTULO IV. Disposiciones sectoriales . . ....
# 3  12\nCAPÍTULO II. Ficheros de titularidad priva...
# 4  15\nTÍTULO V. Movimiento internacional de dato...
# 5  15\nTÍTULO VI. Agencia de Protección de Datos ...
# 6  18\nBOLETÍN OFICIAL DEL ESTADO\nLEGISLACIÓN CO...
# 7  19\nTÍTULO VII. Infracciones y sanciones. . . ...
# 8  19\nDisposiciones adicionales . . . . . . . . ...
# 9  Maleantes y de Peligrosidad y Rehabilitación S...
#  Ley_Organica_15_1999: 69 bloques extraídos
# [✔] Ya existe: Ley_13500_Andalucia.pdf
#              Documento                    Artículo N  \
# 0  Ley_13500_Andalucia  Sección Octava. Procedimien-
# 1  Ley_13500_Andalucia                             2
# 2  Ley_13500_Andalucia                             3
# 3  Ley_13500_Andalucia                             4
# 4  Ley_13500_Andalucia                             5
# 5  Ley_13500_Andalucia                             6
# 6  Ley_13500_Andalucia                             7
# 7  Ley_13500_Andalucia                             8
# 8  Ley_13500_Andalucia                             9
# 9  Ley_13500_Andalucia                            10
#
#                                         Vista previa
# 0  to 8662025 . . . . . . . . . . . . . . . . . ....
# 1  Este Convenio afecta a todos los trabajadoresa...
# 2  El presente Convenio será de aplicación en tod...
# 3  1. Vigencia. El presente Convenio Colectivo en...
# 4  Se acuerda un incremento salarial para el año ...
# 5  Las condiciones de cualquier clase pactadas en...
# 6  Toda cláusula contractual que sea contraria a ...
# 7  A. A fecha de la firma del presente convenio a...
# 8  Cuando concurran causas económicas, técnicas, ...
# 9  1. Se constituye una Comisión Paritaria para l...
#  Ley_13500_Andalucia: 48 bloques extraídos

# %%
# Crear carpeta temporal para guardar PDFs
# Crear carpetas si no existen
output_dir = Path("jsons_articulos")
output_dir.mkdir(parents=True, exist_ok=True)

pdf_dir = Path("temp_pdfs")
pdf_dir.mkdir(parents=True, exist_ok=True)

# %%
# Ruta de salida
json_salida = output_dir / "bloques_legales_unificado.json"

# Guardar los artículos unificados
with open(json_salida, "w", encoding="utf-8") as f:
    json.dump(articulos_totales, f, ensure_ascii=False, indent=2)
    print(f" JSON unificado guardado en: {json_salida}")
# Out:
# ✅ JSON unificado guardado en: jsons_articulos\bloques_legales_unificado.json

# %% [markdown]
# # Fase 2 -Extracción de información semántica
# Este notebook lee documentos PDF legales desde la carpeta data/, los limpia, extrae los artículos y normaliza su contenido

# %%
# !pip install --upgrade openai -q
# !pip install --upgrade requests -q

# %%
from openai import OpenAI
import requests
# Configurar la API Key de OpenAI
openai.api_key ="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"
client = OpenAI(api_key=openai.api_key)

# Crear carpeta de salida dentro de /Notebooks/
output_dir = Path("Notebooks/jsons_semanticos")
output_dir.mkdir(parents=True, exist_ok=True)

# %%
# Leer el archivo JSON desde GitHub (Fase 1)
url_json = "https://raw.githubusercontent.com/JuanC-1976/TFM-R46-GrafosLegales/main/Notebooks/bloques_legales_unificado.json"
respuesta = requests.get(url_json)

# Convertir a lista de artículos
articulos = respuesta.json()
print(f" Se cargaron {len(articulos)} bloques legales desde GitHub.")
# Out:
#  Se cargaron 466 bloques legales desde GitHub.

# %%
# Función que envía cada bloque a GPT-4o y devuelve respuesta estructurada
def analizar_bloque_con_gpt(bloque_texto):
    try:
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": (
                    "Extrae entidades legales y relaciones del texto siguiente en formato JSON. "
                    "El JSON debe tener: documento, tipo, fecha, vigente, relaciones (lista de dicts)."
                )},
                {"role": "user", "content": bloque_texto}
            ],
            temperature=0.2
        )

        # Acceder correctamente al contenido según nueva API
        contenido = response.choices[0].message.content.strip()
        if not contenido:
            print("⚠️ Respuesta vacía del modelo.")
            return None
        try:
            return json.loads(contenido)
        except json.JSONDecodeError as e:
            print("❌ Error decodificando JSON:", e)
            print("🔍 Respuesta cruda del modelo:", contenido)
            return None


   # except Exception as e:
    #    print("❌ Error procesando bloque:", e)
     #   return None

# %%
import json
from tqdm import tqdm

resultados_semanticos = []

# Procesar todos los bloques
for i, bloque in enumerate(tqdm(articulos, desc="Procesando bloques")):
    print(f"🔎 Procesando bloque {i+1}/{len(articulos)}")
    resultado = analizar_bloque_con_gpt(bloque["Contenido"])
    if resultado:
        resultado["documento_origen"] = bloque["Documento"]
        resultados_semanticos.append(resultado)

# Convertir a DataFrame
df_semanticos = pd.DataFrame(resultados_semanticos)

# Guardar como JSON estructurado
json_salida = output_dir / "bloques_semanticos.json"
with open(json_salida, "w", encoding="utf-8") as f:
    json.dump(resultados_semanticos, f, ensure_ascii=False, indent=2)

print(f"\n✅ Se procesaron correctamente {len(df_semanticos)} de {len(articulos)} bloques.")
print(f"📁 Archivo guardado: {json_salida}")

# Mostrar primeras filas
pd.set_option("display.max_colwidth", 180)
display(df_semanticos[["documento_origen", "tipo", "fecha", "vigente", "relaciones"]].head(5))

# %%
# Convertir los resultados enriquecidos a DataFrame
df_semanticos = pd.DataFrame(resultados_semanticos)

# Mostrar resumen
print(f" Se procesaron correctamente {len(df_semanticos)} de {len(articulos)} bloques.")

# Mostrar vista previa
pd.set_option("display.max_colwidth", 180)
display(df_semanticos[["documento_origen", "tipo", "fecha", "vigente", "relaciones"]].head(5))
# Out:
#  Se procesaron correctamente 0 de 466 bloques.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[133], line 9
#       7 # Mostrar vista previa
#       8 pd.set_option("display.max_colwidth", 180)
# ----> 9 display(df_semanticos[["documento_origen", "tipo", "fecha", "vigente", "relaciones"]].head(5))
#
# File ~\anaconda3\envs\TFM\lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\envs\TFM\lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\envs\TFM\lib\site-packages\pandas\core\indexes\base.py:6261, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6259 if nmissing:
#    6260     if nmissing == len(indexer):
# -> 6261         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6264     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['documento_origen', 'tipo', 'fecha', 'vigente', 'relaciones'], dtype='object')] are in the [columns]"

# %%
import json

# ✅ Elegir el primer bloque para test
bloque_prueba = articulos[0]["Contenido"]

# ✅ Enviar a GPT-4o (sin json.loads aún)
response_test = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {
            "role": "system",
            "content": (
                "Extrae entidades legales y relaciones del texto siguiente en formato JSON. "
                "El JSON debe tener los campos: documento, tipo, fecha, vigente, relaciones (lista de dicts)."
            )
        },
        {
            "role": "user",
            "content": bloque_prueba
        }
    ],
    temperature=0.2
)

# ✅ Mostrar texto crudo recibido
texto_bruto = response_test.choices[0].message.content
print("📄 Respuesta cruda del modelo:\n", texto_bruto)

# ✅ Limpiar si viene con triple backticks
if "```json" in texto_bruto:
    texto_bruto = texto_bruto.split("```json")[-1]
if "```" in texto_bruto:
    texto_bruto = texto_bruto.split("```")[0]

# ✅ Intentar parsear el JSON
try:
    resultado_json = json.loads(texto_bruto)
    print("\n✅ JSON estructurado correctamente:")
    display(resultado_json)
except Exception as e:
    print("\n❌ Error al convertir a JSON:", e)
# Out:
# 📄 Respuesta cruda del modelo:
#  ```json
# {
#   "documento": "BOE-A-2018-16673",
#   "tipo": "BOLETÍN OFICIAL DEL ESTADO",
#   "fecha": "2018-12-06",
#   "vigente": true,
#   "relaciones": []
# }
# ```
#
# ✅ JSON estructurado correctamente:
# {'documento': 'BOE-A-2018-16673',
#  'tipo': 'BOLETÍN OFICIAL DEL ESTADO',
#  'fecha': '2018-12-06',
#  'vigente': True,
#  'relaciones': []}

# %%
resultados_semanticos = []

# Probar con pocos al inicio: articulos[:3]
for i, bloque in enumerate(articulos):
    print(f"🧠 Procesando bloque {i+1}/{len(articulos)}")
    resultado = analizar_bloque_con_gpt(bloque["Contenido"])
    if resultado:
        resultado["documento_origen"] = bloque["Documento"]
        resultados_semanticos.append(resultado)

print(f"\n Total de bloques enriquecidos: {len(resultados_semanticos)}")
# Out:
# 🧠 Procesando bloque 1/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 2/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 3/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 4/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 5/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 6/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 7/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 8/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 9/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 10/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 11/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 12/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 13/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 14/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 15/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 16/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 17/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 18/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 19/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 20/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 21/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 22/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 23/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 24/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 25/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 26/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 27/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 28/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 29/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 30/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 31/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 32/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 33/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 34/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 35/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 36/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 37/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 38/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 39/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 40/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 41/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 42/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 43/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 44/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 45/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 46/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 47/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 48/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 49/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 50/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 51/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 52/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 53/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 54/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 55/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 56/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 57/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 58/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 59/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 60/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 61/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 62/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 63/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 64/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 65/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 66/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 67/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 68/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 69/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 70/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 71/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 72/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 73/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 74/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 75/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 76/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 77/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 78/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 79/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 80/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 81/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 82/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 83/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 84/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 85/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 86/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 87/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 88/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 89/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 90/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 91/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 92/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 93/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 94/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 95/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 96/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 97/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 98/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 99/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 100/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 101/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 102/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 103/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 104/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 105/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 106/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 107/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 108/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 109/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 110/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 111/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 112/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 113/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 114/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 115/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 116/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 117/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 118/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 119/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 120/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 121/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 122/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 123/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 124/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 125/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 126/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 127/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 128/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 129/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 130/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 131/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 132/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 133/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 134/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 135/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 136/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 137/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 138/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 139/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 140/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 141/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 142/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 143/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 144/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 145/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 146/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 147/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 148/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 149/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 150/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 151/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 152/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 153/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 154/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 155/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 156/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 157/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 158/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 159/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 160/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 161/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 162/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 163/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 164/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 165/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 166/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 167/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 168/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 169/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 170/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 171/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 172/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 173/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 174/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 175/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 176/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 177/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 178/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 179/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 180/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 181/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 182/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 183/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 184/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 185/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 186/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 187/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 188/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 189/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 190/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 191/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 192/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 193/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 194/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 195/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 196/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 197/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 198/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 199/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 200/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 201/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 202/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 203/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 204/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 205/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 206/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 207/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 208/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 209/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 210/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 211/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 212/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 213/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 214/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 215/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 216/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 217/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 218/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 219/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 220/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 221/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 222/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 223/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 224/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 225/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 226/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 227/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 228/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 229/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 230/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 231/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 232/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 233/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 234/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 235/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 236/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 237/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 238/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 239/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 240/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 241/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 242/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 243/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 244/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 245/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 246/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 247/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 248/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 249/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 250/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 251/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 252/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 253/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 254/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 255/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 256/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 257/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 258/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 259/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 260/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 261/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 262/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 263/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 264/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 265/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 266/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 267/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 268/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 269/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 270/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 271/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 272/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 273/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 274/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 275/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 276/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 277/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 278/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 279/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 280/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 281/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 282/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 283/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 284/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 285/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 286/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 287/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 288/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 289/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 290/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 291/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 292/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 293/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 294/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 295/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 296/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 297/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 298/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 299/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 300/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 301/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 302/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 303/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 304/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 305/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 306/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 307/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 308/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 309/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 310/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 311/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 312/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 313/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 314/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 315/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 316/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 317/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 318/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 319/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 320/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 321/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 322/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 323/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 324/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 325/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 326/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 327/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 328/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 329/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 330/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 331/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 332/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 333/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 334/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 335/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 336/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 337/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 338/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 339/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 340/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 341/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 342/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 343/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 344/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 345/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 346/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 347/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 348/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 349/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 350/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 351/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 352/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 353/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 354/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 355/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 356/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 357/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 358/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 359/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 360/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 361/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 362/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 363/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 364/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 365/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 366/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 367/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 368/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 369/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 370/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 371/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 372/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 373/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 374/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 375/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 376/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 377/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 378/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 379/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 380/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 381/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 382/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 383/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 384/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 385/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 386/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 387/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 388/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 389/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 390/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 391/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 392/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 393/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 394/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 395/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 396/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 397/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 398/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 399/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 400/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 401/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 402/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 403/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 404/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 405/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 406/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 407/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 408/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 409/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 410/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 411/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 412/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 413/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 414/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 415/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 416/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 417/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 418/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 419/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 420/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 421/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 422/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 423/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 424/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 425/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 426/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 427/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 428/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 429/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 430/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 431/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 432/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 433/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 434/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 435/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 436/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 437/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 438/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 439/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 440/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 441/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 442/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 443/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 444/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 445/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 446/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 447/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 448/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 449/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 450/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 451/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 452/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 453/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 454/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 455/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 456/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 457/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 458/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 459/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 460/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 461/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 462/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 463/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 464/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 465/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
# 🧠 Procesando bloque 466/466
# ❌ Error procesando bloque: 'OpenAI' object has no attribute 'Chat'
#
#  Total de bloques enriquecidos: 0

# %%
# Guardar como JSON enriquecido
ruta_salida = output_dir / "bloques_semanticos.json"
with open(ruta_salida, "w", encoding="utf-8") as f:
    json.dump(resultados_semanticos, f, ensure_ascii=False, indent=2)

print(f"Archivo guardado en: {ruta_salida.resolve()}")
